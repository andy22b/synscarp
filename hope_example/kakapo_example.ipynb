# %% [markdown]
# Import modules requires for running

# %%
import geopandas as gpd
from synthetic_offsets.dem import deform_dem
from synthetic_offsets.fault import Fault
from synthetic_offsets.io.array_operations import profile_tiff_along_linestring
import numpy as np
from matplotlib import pyplot as plt
import os.path

from itertools import product

# %% [markdown]
# Supply names of DEM, fault trace shapefile (both NZTM) and fault source parameters

# %%
dem = "BU23.tif"
trace = "simplified_kakapo.geojson"

# %%
slip_values = np.array([4., 10., 20., 40.])
rake_values = np.array([180., 175., 170.])

# %% [markdown]
# Create deformed DEM (may throw up a warning but should still run)

# %%
for slip, rake in product(slip_values, rake_values):
    rounded_slip = f"{int(np.round(slip, 0)):d}"
    rounded_rake= f"{int(np.round(rake, 0)):d}"
    deformed_dem = f"kakapo_backslip_slip{rounded_slip}_rake{rounded_rake}.tif"
    print(deformed_dem)
    fault = Fault(trace=trace, dip=80., boundary=dem, slip=-slip, rake=rake, dip_direction=340.)
    if not os.path.exists(deformed_dem):
        hw, fw = fault.footwall_and_hangingwall_polygons(fault.clipped_trace)
        e, n, u = fault.slip_and_rake
        hw_shifted, clipped_fw = fault.moved_footwall_hangingwall_polygons(fault.clipped_trace, x_shift=e, y_shift=n)
        holes = gpd.GeoSeries(hw.difference(hw_shifted), crs=2193)
        deform_dem(dem, deformed_dem, hw_shifted, clipped_fw, holes, e, n, u)
# Out:
# kakapo_backslip_slip4_rake180.tif
# Initializing Fault object...
# Dip direction (azimuth is 340.00)
# Change by overriding or using flip_dip_direction option...
# kakapo_backslip_slip4_rake175.tif
# Initializing Fault object...
# Dip direction (azimuth is 340.00)
# Change by overriding or using flip_dip_direction option...
# kakapo_backslip_slip4_rake170.tif
# Initializing Fault object...
# Dip direction (azimuth is 340.00)
# Change by overriding or using flip_dip_direction option...
# kakapo_backslip_slip10_rake180.tif
# Initializing Fault object...
# Dip direction (azimuth is 340.00)
# Change by overriding or using flip_dip_direction option...
# kakapo_backslip_slip10_rake175.tif
# Initializing Fault object...
# Dip direction (azimuth is 340.00)
# Change by overriding or using flip_dip_direction option...
# kakapo_backslip_slip10_rake170.tif
# Initializing Fault object...
# Dip direction (azimuth is 340.00)
# Change by overriding or using flip_dip_direction option...
# ...

# %%
across_lines = gpd.read_file("across.geojson")
parallel_south = gpd.read_file("parallel_south.geojson")
parallel_north = gpd.read_file("parallel_north.geojson")

# %%
len(across_lines)
# Out:
# 2

# %%
line_dict = {}
plot_dict = {}
for i, line in enumerate(across_lines.geometry.values):
    line_dict[f"across{i}"] = line

line_dict["parallel_south"] = parallel_south.geometry.values[0]
line_dict["parallel_north"] = parallel_north.geometry.values[0]

plt.close("all")
spacing = 1.
colours = ["red", "blue", "green", "orange", "purple", "brown", "pink", "gray", "olive", "cyan"]

for key in line_dict.keys():
    plot_dict[key] = plt.subplots()
    distances, profile_z = profile_tiff_along_linestring(dem, line_dict[key], spacing=1)
    plt.plot(distances, profile_z, label="No backslip", color="black", linestyle="--")
    plt.xlabel("Distance along line (m)")
    plt.ylabel("Elevation (m)")

    for slip, rake, colour in zip(slip_values, rake_values, colours):
        rounded_slip = f"{int(np.round(slip, 0)):d}"
        rounded_rake= f"{int(np.round(rake, 0)):d}"
        deformed_dem = f"kakapo_backslip_slip{rounded_slip}_rake{rounded_rake}.tif"
        distances, profile_z = profile_tiff_along_linestring(deformed_dem, line_dict[key], spacing=1)
        label = f"Slip: {rounded_slip} m, Rake: {rounded_rake}°"
        plt.plot(distances, profile_z, label=label, color=colour)
    plt.legend()

# %%
plt.plot(distances, profile_z)
plt.xlabel("Distance along line (m)")
plt.ylabel("Elevation (m)")
# plt.ylim(613,615)
plt.show()

# %%
# Out:
# np.float64(-9.396926207859085)
